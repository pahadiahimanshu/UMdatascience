# %% [markdown]
#  # Series Data structures

# %%
import pandas as pd

# %% [markdown]
# ## Series from list

# %%
students = ['Alice','Jack','Molly']
pd.Series(students)
# Out:
# 0    Alice
# 1     Jack
# 2    Molly
# dtype: object

# %%
marks = [234,556,613]
pd.Series(marks)
# Out:
# 0    234
# 1    556
# 2    613
# dtype: int64

# %%
# dtype is int64

# %%
students = ['Alice','Jack',None]
pd.Series(students)
# Out:
# 0    Alice
# 1     Jack
# 2     None
# dtype: object

# %%
marks = [234,556,None]
pd.Series(marks)

# Dtype to floating point number
# NaN -> Floating point number
# so, it went ahead and converted the ints to floats
# Out:
# 0    234.0
# 1    556.0
# 2      NaN
# dtype: float64

# %%
import numpy as np
np.nan == None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %% [markdown]
# ## Series from dictionary

# %%
student_scores = {'Alice':'Physics',
                 'Jack':'Chemistry',
                  'Molly':'English'}
s = pd.Series(student_scores)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
s.index
# Out:
# Index(['Alice', 'Jack', 'Molly'], dtype='object')

# %%
# When creating a series using a dictionry and you provide wrong index, it will put NaN in the value

s = pd.Series(student_scores, index=['Alice','Jack','Sam'])
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Sam            NaN
# dtype: object

# %%
pd.isnull(s)
# Out:
# Alice    False
# Jack     False
# Sam       True
# dtype: bool

# %%
import math
math.isnan(s['Sam'])
# Out:
# True

# %%
s['Sam'] == None
# Out:
# False

# %% [markdown]
# ## Series from Tuple

# %%
students = [("Alice","Brown"),("Jack","white"),("Molly","blue")]

# %%
pd.Series(students)
# Out:
# 0    (Alice, Brown)
# 1     (Jack, white)
# 2     (Molly, blue)
# dtype: object

# %% [markdown]
# ## Explicit index for a list

# %%
s = pd.Series(['Physics','Chemistry','English'],index=['Alice','Jack','Molly'])
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %% [markdown]
# # Querying a series

# %%
# index posiiton or index label

# numeric - iloc
# label - loc

# %%
student_classes = {'Alice':'Physics',
                 'Jack':'Chemistry',
                  'Molly':'English',
                  'Sam':'Computer'}
s = pd.Series(student_classes)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam       Computer
# dtype: object

# %%
s.iloc[3]
# Out:
# 'Computer'

# %%
s.loc['Molly']
# Out:
# 'English'

# %%
# indexing operator works on context
# if you pass numeric, it works as iloc
s[3]
# Out:
# 'Computer'

# %%
# if you pass object "Molly", it works as a loc
s['Molly']
# Out:
# 'English'

# %%
# what if index is a list of integers -> Confuses Pandas
class_code = {99:'Physics',100:'Chemistry',101:'English',102:'Computer'}
s = pd.Series(class_code)
s
# Out:
# 99       Physics
# 100    Chemistry
# 101      English
# 102     Computer
# dtype: object

# %%
# s[0] results in error here
s.iloc[0] # but this works
# Out:
# 'Physics'

# %% [markdown]
# # Manipulation

# %%
# average grade

grades = pd.Series([90,80,70,60])
total = 0
for grade in grades:
    total+=grade
print(total/len(grades))
# Out:
# 75.0

# %%
# the above method is slow
# modern computers can do tasks simultaneously
# Pandas and numpy support a method of computation called vectorization

# %%
total = np.sum(grades)
print(total/len(grades))
# Out:
# 75.0

# %%
# let's check if it's faster

numbers = pd.Series(np.random.randint(0,1000,10000))

# %%
numbers.head()
# Out:
# 0    655
# 1    852
# 2    525
# 3     18
# 4    507
# dtype: int64

# %%
# %%timeit -n 100
total = 0
for number in numbers:
    total+=grade
total/len(numbers)
# Out:
# 1.3 ms ± 96.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
total = 0
total = np.sum(numbers)
total/len(numbers)
# Out:
# 73.7 µs ± 11.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## .loc to add new data

# %%
# Indices have mixed types
s = pd.Series([1,2,3])
s.loc['History'] = 102
s
# Out:
# 0            1
# 1            2
# 2            3
# History    102
# dtype: int64

# %% [markdown]
# ## Index not unique

# %%
student_classes = pd.Series({'Alice':'Physics',
                 'Jack':'Chemistry',
                  'Molly':'English',
                 'Sam':'Computer'})
student_classes
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam       Computer
# dtype: object

# %%
kelly_classes = pd.Series(['Philosophy','Arts','Math'],index = ['Kelly','Kelly','Kelly'])

# %%
kelly_classes
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
all_students = student_classes.append(kelly_classes)
all_students
# Out:
# Alice       Physics
# Jack      Chemistry
# Molly       English
# Sam        Computer
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
# append function doesn't actually change the underlying series but returns a new series 
# common pattern in pandas
student_classes
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam       Computer
# dtype: object

# %%
all_students.loc['Kelly']
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %% [markdown]
# # DataFrame

# %%
record1 = pd.Series({'Name':'Alice', 'Class':'Physics', 'Score':85})
record2 = pd.Series({'Name':'Jack', 'Class':'Chemistru', 'Score':82})
record3 = pd.Series({'Name':'Helen', 'Class':'Biology', 'Score':90})

# %%
# Df is indexed
df = pd.DataFrame([record1,record2,record3],
                 index = ['school1','school2','school3'])
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistru     82
# school3  Helen    Biology     90

# %%
students = [{'Name':'Alice', 'Class':'Physics', 'Score':85},
           {'Name':'Jack', 'Class':'Chemistru', 'Score':82},
           {'Name':'Helen', 'Class':'Biology', 'Score':90}]

# %%
df = pd.DataFrame(students,
                 index = ['school1','school2','school3'])
df
# Out:
#           Name      Class  Score
# school1  Alice    Physics     85
# school2   Jack  Chemistru     82
# school3  Helen    Biology     90

# %% [markdown]
# ## loc iloc attributes

# %%
# loc - if we pass single value, it returns the series if there's only one row to return

df.loc['school2']
# name of the series is returned as the index value
# Out:
# Name          Jack
# Class    Chemistru
# Score           82
# Name: school2, dtype: object

# %%
type(df.loc['school2'])
# Out:
# pandas.core.series.Series

# %%
# returns second series in the df
df.iloc[1]
# Out:
# Name          Jack
# Class    Chemistru
# Score           82
# Name: school2, dtype: object

# %%
# let's add one more series
newstudent = pd.DataFrame({'Name':'Alison', 'Class':'Computer', 'Score':99},index=['school1'])
newstudent
# Out:
#            Name     Class  Score
# school1  Alison  Computer     99

# %%
dfnew = df.append(newstudent)
dfnew
# Out:
#            Name      Class  Score
# school1   Alice    Physics     85
# school2    Jack  Chemistru     82
# school3   Helen    Biology     90
# school1  Alison   Computer     99

# %%
dfnew.loc['school1']
# Out:
#            Name     Class  Score
# school1   Alice   Physics     85
# school1  Alison  Computer     99

# %%
type(dfnew.loc['school1'])
# when there are more than two rows for a query, it returns a dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### loc attribute allows to access data based on multiple axes

# %%
# Returns series
dfnew.loc['school1','Name']
# Out:
# school1     Alice
# school1    Alison
# Name: Name, dtype: object

# %%
# returns string
df.loc['school1','Name']
# Out:
# 'Alice'

# %%
df.iloc[1]
# Out:
# Name          Jack
# Class    Chemistru
# Score           82
# Name: school2, dtype: object

# %% [markdown]
# # Select single column?

# %%
# transpose
df.T
# Out:
#        school1    school2  school3
# Name     Alice       Jack    Helen
# Class  Physics  Chemistru  Biology
# Score       85         82       90

# %%
df.T.loc['Name']
# Out:
# school1    Alice
# school2     Jack
# school3    Helen
# Name: Name, dtype: object

# %%
# loc and iloc are for row use
# for dataframe, panda reserves the indexing operator for column selection

# %%
dfnew
# Out:
#            Name      Class  Score
# school1   Alice    Physics     85
# school2    Jack  Chemistru     82
# school3   Helen    Biology     90
# school1  Alison   Computer     99

# %%
df['Name']
# df.loc['Name'] will give error, since no row having label 'Name'
# Out:
# school1    Alice
# school2     Jack
# school3    Helen
# Name: Name, dtype: object

# %%
dfnew.loc['school1',['Name','Class']]
# Out:
#            Name     Class
# school1   Alice   Physics
# school1  Alison  Computer

# %% [markdown]
# ### if we want to select all rows, we can use colon : (just like string slicing)

# %%
df.loc[:,['Name']]
# Out:
#           Name
# school1  Alice
# school2   Jack
# school3  Helen

# %% [markdown]
# ## Drop

# %%
dfnew.drop('school1')
# Out:
#           Name      Class  Score
# school2   Jack  Chemistru     82
# school3  Helen    Biology     90

# %%
# didn't change the actual dfnew
dfnew
# Out:
#            Name      Class  Score
# school1   Alice    Physics     85
# school2    Jack  Chemistru     82
# school3   Helen    Biology     90
# school1  Alison   Computer     99

# %%
# two optional parameters -
# inplace - dataframe will be updated, instead of copy being returned
# Axis - which should be dropped, by default it's 0 -> row axes. If we want to drop column -> 1

# %%
dfx = dfnew.copy()

# %%
dfx.drop("Name", inplace=True,axis=1)
dfx
# Out:
#              Class  Score
# school1    Physics     85
# school2  Chemistru     82
# school3    Biology     90
# school1   Computer     99

# %%
del dfx['Class']
dfx
# Out:
#          Score
# school1     85
# school2     82
# school3     90
# school1     99

# %% [markdown]
# ## add column

# %%
# use indexing 
dfnew['ClassRank'] = None
dfnew
# Out:
#            Name      Class  Score ClassRank
# school1   Alice    Physics     85      None
# school2    Jack  Chemistru     82      None
# school3   Helen    Biology     90      None
# school1  Alison   Computer     99      None

# %% [markdown]
# # DF indexing and loading

# %%
# !cat Admission_Predict.csv
# Serial No.,GRE Score,TOEFL Score,University Rating,SOP,LOR ,CGPA,Research,Chance of Admit

# %%
df = pd.read_csv('Admission_Predict.csv')
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# now it treats serial no from the dataset as the index
df = pd.read_csv('Admission_Predict.csv',index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
new_df = df.rename(columns={'GRE Score':'GRE','TOEFL Score':'TOEFL','University Rating':'Uni Rate',
                           'SOP':'SOP','LOR':'LOR','CGPA':'CGPA','Research':'Research','Chance of Admit ':'Admit Prediction'
                           })

# %%
new_df.head()
# Out:
#             GRE  TOEFL  Uni Rate  SOP  LOR   CGPA  Research  Admit Prediction
# Serial No.
# 1           337    118         4  4.5   4.5  9.65         1              0.92
# 2           324    107         4  4.0   4.5  8.87         1              0.76
# 3           316    104         3  3.0   3.5  8.00         1              0.72
# 4           322    110         3  3.5   2.5  8.67         1              0.80
# 5           314    103         2  2.0   3.0  8.21         0              0.65

# %%
new_df.columns
# Out:
# Index(['GRE', 'TOEFL', 'Uni Rate', 'SOP', 'LOR ', 'CGPA', 'Research',
#        'Admit Prediction'],
#       dtype='object')

# %%
# we can also clean the columns by passing a function
new_df = new_df.rename(mapper=str.strip, axis='columns')
new_df.columns

# notice LOR
# Out:
# Index(['GRE', 'TOEFL', 'Uni Rate', 'SOP', 'LOR', 'CGPA', 'Research',
#        'Admit Prediction'],
#       dtype='object')

# %%
cols = list(df.columns)

# %%
cols = [x.lower().strip() for x in cols]
df.columns = cols

# %%
df.columns
# Out:
# Index(['gre score', 'toefl score', 'university rating', 'sop', 'lor', 'cgpa',
#        'research', 'chance of admit'],
#       dtype='object')

# %% [markdown]
# # Querying a df

# %% [markdown]
# ## Boolean masking

# %%
df = pd.read_csv('Admission_Predict.csv',index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
cols = [x.lower().strip() for x in df.columns]
df.columns = cols

df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
admit_mask = df['chance of admit'] > 0.7
admit_mask.head()
# Out:
# Serial No.
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# Name: chance of admit, dtype: bool

# %% [markdown]
# ### Now we can lay it on top of data, to hide unwanted data

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
df[df['chance of admit'] > 0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %% [markdown]
# ## Indexing

# %%
df['gre score'].head()
# Out:
# Serial No.
# 1    337
# 2    324
# 3    316
# 4    322
# 5    314
# Name: gre score, dtype: int64

# %%
df[['gre score','lor']].head()
# Out:
#             gre score  lor
# Serial No.
# 1                 337  4.5
# 2                 324  4.5
# 3                 316  3.5
# 4                 322  2.5
# 5                 314  3.0

# %% [markdown]
# ## Combining multiple bool masks

# %%
# Paranthesis are necessary
((df['gre score'] > 0.7) & (df['gre score'] < 0.9)).head()
# Out:
# Serial No.
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: gre score, dtype: bool

# %%
# Another way
(df['gre score'].gt(0.7) & df['gre score'].lt(0.9)).head()
# Out:
# Serial No.
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# Name: gre score, dtype: bool

# %% [markdown]
# # Indexing

# %%
df = pd.read_csv('Admission_Predict.csv', index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
# let's set index to chance of admit instead of Serial no.
# But preserve the current index
df['Serial Number'] = df.index
df = df.set_index('Chance of Admit ')
df.head()
# Out:
#                   GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Chance of Admit
# 0.92                    337          118                  4  4.5   4.5  9.65
# 0.76                    324          107                  4  4.0   4.5  8.87
# 0.72                    316          104                  3  3.0   3.5  8.00
# 0.80                    322          110                  3  3.5   2.5  8.67
# 0.65                    314          103                  2  2.0   3.0  8.21
#
#                   Research  Serial Number
# Chance of Admit
# 0.92                     1              1
# 0.76                     1              2
# 0.72                     1              3
# 0.80                     1              4
# 0.65                     0              5

# %%
df = df.reset_index()
df.head()
# Out:
#    Chance of Admit   GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0              0.92        337          118                  4  4.5   4.5
# 1              0.76        324          107                  4  4.0   4.5
# 2              0.72        316          104                  3  3.0   3.5
# 3              0.80        322          110                  3  3.5   2.5
# 4              0.65        314          103                  2  2.0   3.0
#
#    CGPA  Research  Serial Number
# 0  9.65         1              1
# 1  8.87         1              2
# 2  8.00         1              3
# 3  8.67         1              4
# 4  8.21         0              5

# %% [markdown]
# ## Multi-level indxing
# - Composite key in relational db
# - set index with a list of columns

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %%
# There are two summarized levels - summary data for the whole country & summary data for each state
df['SUMLEV'].unique()
# Out:
# array([40, 50])

# %%
# 40 and 50
# Let's exclude all of rows at state level and just keep county data
df = df[df['SUMLEV'] == 50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
# 5         -1.177622         -1.748766         -2.062535         -1.369970
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
# 5     1.859511    -0.848580    -1.402476    -1.577232    -0.884411
#
# [5 rows x 100 columns]

# %%
columns_to_keep = ['STNAME','CTYNAME','BIRTHS2010','BIRTHS2011','BIRTHS2012','BIRTHS2013','BIRTHS2014','BIRTHS2015',
                  'POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015',]
df = df[columns_to_keep]
df.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 1         623         600            55175            55038            55290
# 2        2186        2240           190396           195126           199713
# 3         260         269            27159            26973            26815
# 4         247         253            22642            22512            22549
# 5         618         603            57776            57734            57658
#
#    POPESTIMATE2015
# 1            55347
# 2           203709
# 3            26489
# 4            22583
# 5            57673

# %%
# The data above has two indexes -> STNAME and CTYNAME

# %%
df = df.set_index(['STNAME','CTYNAME'])
df.head()
# Out:
#                         BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Autauga County         151         636         615         574
#         Baldwin County         517        2187        2092        2160
#         Barbour County          70         335         300         283
#         Bibb County             44         266         245         259
#         Blount County          183         744         710         646
#
#                         BIRTHS2014  BIRTHS2015  POPESTIMATE2012  \
# STNAME  CTYNAME
# Alabama Autauga County         623         600            55175
#         Baldwin County        2186        2240           190396
#         Barbour County         260         269            27159
#         Bibb County            247         253            22642
#         Blount County          618         603            57776
#
#                         POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# STNAME  CTYNAME
# Alabama Autauga County            55038            55290            55347
#         Baldwin County           195126           199713           203709
#         Barbour County            26973            26815            26489
#         Bibb County               22512            22549            22583
#         Blount County             57734            57658            57673

# %% [markdown]
# ## Query this data

# %%
df.loc['Michigan','Washtenaw County']
# type(df.loc['Michigan','Washtenaw County'])
# Out:
# BIRTHS2010            977
# BIRTHS2011           3826
# BIRTHS2012           3780
# BIRTHS2013           3662
# BIRTHS2014           3683
# BIRTHS2015           3709
# POPESTIMATE2012    351213
# POPESTIMATE2013    354289
# POPESTIMATE2014    357029
# POPESTIMATE2015    358880
# Name: (Michigan, Washtenaw County), dtype: int64

# %%
# Comparison of two counties
df.loc[ [
            ('Michigan','Washtenaw County'),
            ('Michigan','Wayne County')
            ]
        ]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         977        3826        3780        3662
#          Wayne County            5918       23819       23270       23377
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2012  \
# STNAME   CTYNAME
# Michigan Washtenaw County        3683        3709           351213
#          Wayne County           23607       23586          1792514
#
#                            POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County           354289           357029           358880
#          Wayne County              1775713          1766008          1759335

# %% [markdown]
# # Missing values

# %%
df = pd.read_csv('class_grades.csv')
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17      NaN     63.15  48.89
# 3       7         NaN       NaN    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %% [markdown]
# ## is null

# %%
mask = df.isnull()
mask.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0   False       False     False    False     False  False
# 1   False       False     False    False     False  False
# 2   False       False     False     True     False  False
# 3   False        True      True    False     False  False
# 4   False       False     False    False     False  False

# %% [markdown]
# ## Drop na

# %%
df.dropna().head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 4       8       91.32     93.64    95.00    107.41  73.89
# 5       7       95.00     92.58    93.12     97.78  68.06
# 6       8       95.05    102.99    56.25     99.07  50.00

# %% [markdown]
# ## Fillna

# %%
# Allows you to change all missing values to one scalar value
df.fillna(0,inplace=True)
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17     0.00     63.15  48.89
# 3       7        0.00      0.00    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %% [markdown]
# ## na_filter

# %%
# option use to turn off whitespace filtering
# if whitespace is an actual value of interest (RARE)
# If data is without any NAs, passing na_filter = False can improve performance while reading a large file

# %%
df = pd.read_csv('log.csv')
df
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# 12  1469974524     sue  advanced.html                 25    NaN     NaN
# 13  1469974424     sue  advanced.html                 23  False    10.0
# 14  1469974554     sue  advanced.html                 26    NaN     NaN
# 15  1469974624     sue  advanced.html                 27    NaN     NaN
# 16  1469974654     sue  advanced.html                 28    NaN     5.0
# 17  1469974724     sue  advanced.html                 29    NaN     NaN
# 18  1469974484  cheryl     intro.html                  7    NaN     NaN
# 19  1469974514  cheryl     intro.html                  8    NaN     NaN
# 20  1469974754     sue  advanced.html                 30    NaN     NaN
# 21  1469974824     sue  advanced.html                 31    NaN     NaN
# 22  1469974854     sue  advanced.html                 32    NaN     NaN
# 23  1469974924     sue  advanced.html                 33    NaN     NaN
# 24  1469977424     bob     intro.html                  1   True    10.0
# 25  1469977454     bob     intro.html                  1    NaN     NaN
# 26  1469977484     bob     intro.html                  1    NaN     NaN
# 27  1469977634     bob     intro.html                  1    NaN     NaN
# 28  1469977664     bob     intro.html                  1    NaN     NaN
# 29  1469974634  cheryl     intro.html                 12    NaN     NaN
# 30  1469974664  cheryl     intro.html                 13    NaN     NaN
# 31  1469977694     bob     intro.html                  1    NaN     NaN
# 32  1469977724     bob     intro.html                  1    NaN     NaN

# %% [markdown]
# ## Method parameters - ffill and bfill

# %% [markdown]
# - ffill is for forward filling and it updates an NaN for a particular cell with a value from the previous row
# - bfill is backward filling
# - Data needs to be sorted for this to work

# %% [markdown]
# ### Sort either by index or timestamp

# %%
df = df.set_index('time')
df = df.sort_index()
df
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974624     sue  advanced.html                 27    NaN     NaN
# 1469974634  cheryl     intro.html                 12    NaN     NaN
# 1469974654     sue  advanced.html                 28    NaN     5.0
# 1469974664  cheryl     intro.html                 13    NaN     NaN
# 1469974694  cheryl     intro.html                 14    NaN     NaN
# 1469974724  cheryl     intro.html                 15    NaN     NaN
# 1469974724     sue  advanced.html                 29    NaN     NaN
# 1469974754     sue  advanced.html                 30    NaN     NaN
# 1469974824     sue  advanced.html                 31    NaN     NaN
# 1469974854     sue  advanced.html                 32    NaN     NaN
# 1469974924     sue  advanced.html                 33    NaN     NaN
# 1469977424     bob     intro.html                  1   True    10.0
# 1469977454     bob     intro.html                  1    NaN     NaN
# 1469977484     bob     intro.html                  1    NaN     NaN
# 1469977514     bob     intro.html                  1    NaN     NaN
# 1469977544     bob     intro.html                  1    NaN     NaN
# 1469977574     bob     intro.html                  1    NaN     NaN
# 1469977604     bob     intro.html                  1    NaN     NaN
# 1469977634     bob     intro.html                  1    NaN     NaN
# 1469977664     bob     intro.html                  1    NaN     NaN
# 1469977694     bob     intro.html                  1    NaN     NaN
# 1469977724     bob     intro.html                  1    NaN     NaN

# %%
# as we can see timestamp can be same when two users are using the system
# Let's use multi-level indexing

# %%
# df = df.reset_index()
# df = df.set_index(['time','user'])
# df.head()

# %%
df = df.fillna(method = 'ffill')
df.head()
# Out:
#                            video  playback position  paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5   False    10.0
#            sue     advanced.html                 23   False    10.0
# 1469974454 cheryl     intro.html                  6   False    10.0
#            sue     advanced.html                 24   False    10.0
# 1469974484 cheryl     intro.html                  7   False    10.0

# %% [markdown]
# ## customized fill-in using replace()

# %%
df = pd.DataFrame({'A':[1,1,2,3,4],
                   'B':[3,6,3,8,9],
                   'C':['a','b','c','d','e']})
df
# Out:
#    A  B  C
# 0  1  3  a
# 1  1  6  b
# 2  2  3  c
# 3  3  8  d
# 4  4  9  e

# %%
# we can replace 1 with 100
df.replace(1,100)
# Out:
#      A  B  C
# 0  100  3  a
# 1  100  6  b
# 2    2  3  c
# 3    3  8  d
# 4    4  9  e

# %%
# Changing 1 to 100, 3 to 300
df.replace([1,3],[100,300])
# Out:
#      A    B  C
# 0  100  300  a
# 1  100    6  b
# 2    2  300  c
# 3  300    8  d
# 4    4    9  e

# %%
df = pd.read_csv('log.csv')
df.head()
# Out:
#          time    user       video  playback position paused  volume
# 0  1469974424  cheryl  intro.html                  5  False    10.0
# 1  1469974454  cheryl  intro.html                  6    NaN     NaN
# 2  1469974544  cheryl  intro.html                  9    NaN     NaN
# 3  1469974574  cheryl  intro.html                 10    NaN     NaN
# 4  1469977514     bob  intro.html                  1    NaN     NaN

# %%
# replace using regex
# first parameter to replace the pattern we want to match
# second parameter is the value we want to emit upon match
# third parameter = regex = True

# %%
df.replace("[s]*.html"," webpage",regex=True)
# Out:
#           time    user             video  playback position paused  volume
# 0   1469974424  cheryl     intro webpage                  5  False    10.0
# 1   1469974454  cheryl     intro webpage                  6    NaN     NaN
# 2   1469974544  cheryl     intro webpage                  9    NaN     NaN
# 3   1469974574  cheryl     intro webpage                 10    NaN     NaN
# 4   1469977514     bob     intro webpage                  1    NaN     NaN
# 5   1469977544     bob     intro webpage                  1    NaN     NaN
# 6   1469977574     bob     intro webpage                  1    NaN     NaN
# 7   1469977604     bob     intro webpage                  1    NaN     NaN
# 8   1469974604  cheryl     intro webpage                 11    NaN     NaN
# 9   1469974694  cheryl     intro webpage                 14    NaN     NaN
# 10  1469974724  cheryl     intro webpage                 15    NaN     NaN
# 11  1469974454     sue  advanced webpage                 24    NaN     NaN
# 12  1469974524     sue  advanced webpage                 25    NaN     NaN
# 13  1469974424     sue  advanced webpage                 23  False    10.0
# 14  1469974554     sue  advanced webpage                 26    NaN     NaN
# 15  1469974624     sue  advanced webpage                 27    NaN     NaN
# 16  1469974654     sue  advanced webpage                 28    NaN     5.0
# 17  1469974724     sue  advanced webpage                 29    NaN     NaN
# 18  1469974484  cheryl     intro webpage                  7    NaN     NaN
# 19  1469974514  cheryl     intro webpage                  8    NaN     NaN
# 20  1469974754     sue  advanced webpage                 30    NaN     NaN
# 21  1469974824     sue  advanced webpage                 31    NaN     NaN
# 22  1469974854     sue  advanced webpage                 32    NaN     NaN
# 23  1469974924     sue  advanced webpage                 33    NaN     NaN
# 24  1469977424     bob     intro webpage                  1   True    10.0
# 25  1469977454     bob     intro webpage                  1    NaN     NaN
# 26  1469977484     bob     intro webpage                  1    NaN     NaN
# 27  1469977634     bob     intro webpage                  1    NaN     NaN
# 28  1469977664     bob     intro webpage                  1    NaN     NaN
# 29  1469974634  cheryl     intro webpage                 12    NaN     NaN
# 30  1469974664  cheryl     intro webpage                 13    NaN     NaN
# 31  1469977694     bob     intro webpage                  1    NaN     NaN
# 32  1469977724     bob     intro webpage                  1    NaN     NaN

# %%
df.replace(".*.html$"," webpage",regex=True)
# Out:
#           time    user     video  playback position paused  volume
# 0   1469974424  cheryl   webpage                  5  False    10.0
# 1   1469974454  cheryl   webpage                  6    NaN     NaN
# 2   1469974544  cheryl   webpage                  9    NaN     NaN
# 3   1469974574  cheryl   webpage                 10    NaN     NaN
# 4   1469977514     bob   webpage                  1    NaN     NaN
# 5   1469977544     bob   webpage                  1    NaN     NaN
# 6   1469977574     bob   webpage                  1    NaN     NaN
# 7   1469977604     bob   webpage                  1    NaN     NaN
# 8   1469974604  cheryl   webpage                 11    NaN     NaN
# 9   1469974694  cheryl   webpage                 14    NaN     NaN
# 10  1469974724  cheryl   webpage                 15    NaN     NaN
# 11  1469974454     sue   webpage                 24    NaN     NaN
# 12  1469974524     sue   webpage                 25    NaN     NaN
# 13  1469974424     sue   webpage                 23  False    10.0
# 14  1469974554     sue   webpage                 26    NaN     NaN
# 15  1469974624     sue   webpage                 27    NaN     NaN
# 16  1469974654     sue   webpage                 28    NaN     5.0
# 17  1469974724     sue   webpage                 29    NaN     NaN
# 18  1469974484  cheryl   webpage                  7    NaN     NaN
# 19  1469974514  cheryl   webpage                  8    NaN     NaN
# 20  1469974754     sue   webpage                 30    NaN     NaN
# 21  1469974824     sue   webpage                 31    NaN     NaN
# 22  1469974854     sue   webpage                 32    NaN     NaN
# 23  1469974924     sue   webpage                 33    NaN     NaN
# 24  1469977424     bob   webpage                  1   True    10.0
# 25  1469977454     bob   webpage                  1    NaN     NaN
# 26  1469977484     bob   webpage                  1    NaN     NaN
# 27  1469977634     bob   webpage                  1    NaN     NaN
# 28  1469977664     bob   webpage                  1    NaN     NaN
# 29  1469974634  cheryl   webpage                 12    NaN     NaN
# 30  1469974664  cheryl   webpage                 13    NaN     NaN
# 31  1469977694     bob   webpage                  1    NaN     NaN
# 32  1469977724     bob   webpage                  1    NaN     NaN

# %% [markdown]
# # Manipulating DataFrames - Data cleaning process

# %%
df = pd.read_csv('presidents.csv')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# 3  85 years, 104 days
# 4   73 years, 67 days

# %%
# Let's separate out firstname and lastname
df['First'] = df['President']

# take anything after space, replace it with nothing
df['First'] = df['First'].replace('[ ].*','',regex=True)
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First
# 0  67 years, 295 days  George
# 1  90 years, 247 days    John
# 2   83 years, 82 days  Thomas
# 3  85 years, 104 days   James
# 4   73 years, 67 days   James

# %%
# Alternative -> Apply function

del(df['First'])
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# 3  85 years, 104 days
# 4   73 years, 67 days

# %%
# Apply function takes some arbitrary function and apply to Series or DataFrame across all rows or columns
# Let's write a function to split the string into two
def splitname(row):
    # Single row series 
    row['First'] = row['President'].split(" ")[0]
    row['Last'] = row['President'].split(" ")[-1]
    return row

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age
# 0  67 years, 295 days
# 1  90 years, 247 days
# 2   83 years, 82 days
# 3  85 years, 104 days
# 4   73 years, 67 days

# %%
# Apply this
df = df.apply(splitname, axis='columns')
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 2  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 3  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 4  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
#
#         Age atend of presidency Post-presidencytimespan          Died  \
# 0  65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 2  65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 3  65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 4  65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# 1  67 years, 295 days  George  Washington
# 2  67 years, 295 days  George  Washington
# 3  67 years, 295 days  George  Washington
# 4  67 years, 295 days  George  Washington

# %% [markdown]
# # It didn't work above, Why?

# %% [markdown]
# ## Extract function
# - Takes a regular expression as input and requires you to set capture groups that correspond to the output columns you are interested in

# %%
# My take 
# pattern = "(?P<First>[\w]*)(?:.* )(?P<Last>[\w]*)"

# Answer
pattern = "(^[\w]*)(?:.* )([\w]*$)"
df['President'].str.extract(pattern).head()
# Out:
#         0           1
# 0  George  Washington
# 1    John       Adams
# 2  Thomas   Jefferson
# 3   James     Madison
# 4   James      Monroe

# %%
pattern = "(?P<First>^[\w]*)(?:.* )(?P<Last>[\w]*$)"
names = df['President'].str.extract(pattern).head()

# %%
df['First']= names['First']
df['Last']= names['Last']

# %%
df.head()
# Out:
#    #          President             Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732[a]  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735[a]  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743[a]  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751[a]  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe     Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# 1  90 years, 247 days    John       Adams
# 2   83 years, 82 days  Thomas   Jefferson
# 3  85 years, 104 days   James     Madison
# 4   73 years, 67 days   James      Monroe

# %%
# Let's clean the born column
# Let's remove footnotes in the born column

# %%
df['Born']=df['Born'].str.extract("(?P<born>[\w]{3} [\w]{1,2}, [\d]{4})").head()

# %%
df.head()
# Out:
#    #          President          Born      Age atstart of presidency  \
# 0  1  George Washington  Feb 22, 1732  57 years, 67 daysApr 30, 1789
# 1  2         John Adams  Oct 30, 1735  61 years, 125 daysMar 4, 1797
# 2  3   Thomas Jefferson  Apr 13, 1743  57 years, 325 daysMar 4, 1801
# 3  4      James Madison  Mar 16, 1751  57 years, 353 daysMar 4, 1809
# 4  5       James Monroe  Apr 28, 1758  58 years, 310 daysMar 4, 1817
#
#          Age atend of presidency Post-presidencytimespan          Died  \
# 0   65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1  65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2  65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3  65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4  66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
#
#                   Age   First        Last
# 0  67 years, 295 days  George  Washington
# 1  90 years, 247 days    John       Adams
# 2   83 years, 82 days  Thomas   Jefferson
# 3  85 years, 104 days   James     Madison
# 4   73 years, 67 days   James      Monroe

# %%
# If we check the type of born column, it's object or str
type(df['Born'][0])
# Out:
# str

# %%
# But pandas has datetime feature
df["Born"] = pd.to_datetime(df["Born"])
df["Born"].head()
# Out:
# 0   1732-02-22
# 1   1735-10-30
# 2   1743-04-13
# 3   1751-03-16
# 4   1758-04-28
# Name: Born, dtype: datetime64[ns]

# %% [markdown]
# # Quiz 2

# %%
d = {'1':'a','2':'b','3':'c','4':'d','5':'e'}
s = pd.Series(d)
s
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
s.iloc[0:3]
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
s.iloc[0:2]
# Out:
# 1    a
# 2    b
# dtype: object

# %%
# Out:
#      #              President       Born       Age atstart of presidency  \
# 0    1      George Washington 1732-02-22   57 years, 67 daysApr 30, 1789
# 1    2             John Adams 1735-10-30   61 years, 125 daysMar 4, 1797
# 2    3       Thomas Jefferson 1743-04-13   57 years, 325 daysMar 4, 1801
# 3    4          James Madison 1751-03-16   57 years, 353 daysMar 4, 1809
# 4    5           James Monroe 1758-04-28   58 years, 310 daysMar 4, 1817
# 5    6      John Quincy Adams        NaT   57 years, 236 daysMar 4, 1825
# 6    7         Andrew Jackson        NaT   61 years, 354 daysMar 4, 1829
# 7    8       Martin Van Buren        NaT    54 years, 89 daysMar 4, 1837
# 8    9    William H. Harrison        NaT    68 years, 23 daysMar 4, 1841
# 9   10             John Tyler        NaT     51 years, 6 daysApr 4, 1841
# 10  11          James K. Polk        NaT   49 years, 122 daysMar 4, 1845
# 11  12         Zachary Taylor        NaT   64 years, 100 daysMar 4, 1849
# 12  13       Millard Fillmore        NaT   50 years, 183 daysJul 9, 1850
# 13  14        Franklin Pierce        NaT   48 years, 101 daysMar 4, 1853
# 14  15         James Buchanan        NaT   65 years, 315 daysMar 4, 1857
# 15  16        Abraham Lincoln        NaT    52 years, 20 daysMar 4, 1861
# 16  17         Andrew Johnson        NaT  56 years, 107 daysApr 15, 1865
# 17  18       Ulysses S. Grant        NaT   46 years, 311 daysMar 4, 1869
# 18  19    Rutherford B. Hayes        NaT   54 years, 151 daysMar 4, 1877
# 19  20      James A. Garfield        NaT   49 years, 105 daysMar 4, 1881
# 20  21      Chester A. Arthur        NaT  51 years, 349 daysSep 19, 1881
# 21  22       Grover Cleveland        NaT   47 years, 351 daysMar 4, 1885
# 22  23      Benjamin Harrison        NaT   55 years, 196 daysMar 4, 1889
# 23  24       Grover Cleveland        NaT   55 years, 351 daysMar 4, 1893
# 24  25       William McKinley        NaT    54 years, 34 daysMar 4, 1897
# 25  26     Theodore Roosevelt        NaT  42 years, 322 daysSep 14, 1901
# 26  27        William H. Taft        NaT   51 years, 170 daysMar 4, 1909
# 27  28         Woodrow Wilson        NaT    56 years, 66 daysMar 4, 1913
# 28  29      Warren G. Harding        NaT   55 years, 122 daysMar 4, 1921
# 29  30        Calvin Coolidge        NaT    51 years, 29 daysAug 2, 1923
# 30  31         Herbert Hoover        NaT   54 years, 206 daysMar 4, 1929
# 31  32  Franklin D. Roosevelt        NaT    51 years, 33 daysMar 4, 1933
# 32  33        Harry S. Truman        NaT  60 years, 339 daysApr 12, 1945
# 33  34   Dwight D. Eisenhower        NaT   62 years, 98 daysJan 20, 1953
# 34  35        John F. Kennedy        NaT  43 years, 236 daysJan 20, 1961
# 35  36      Lyndon B. Johnson        NaT   55 years, 87 daysNov 22, 1963
# 36  37          Richard Nixon        NaT   56 years, 11 daysJan 20, 1969
# 37  38            Gerald Ford        NaT    61 years, 26 daysAug 9, 1974
# 38  39           Jimmy Carter        NaT  52 years, 111 daysJan 20, 1977
# 39  40          Ronald Reagan        NaT  69 years, 349 daysJan 20, 1981
# 40  41      George H. W. Bush        NaT  64 years, 222 daysJan 20, 1989
# 41  42           Bill Clinton        NaT  46 years, 154 daysJan 20, 1993
# 42  43         George W. Bush        NaT  54 years, 198 daysJan 20, 2001
# 43  44           Barack Obama        NaT  47 years, 169 daysJan 20, 2009
#
#               Age atend of presidency Post-presidencytimespan          Died  \
# 0        65 years, 10 daysMar 4, 1797       2 years, 285 days  Dec 14, 1799
# 1       65 years, 125 daysMar 4, 1801      25 years, 122 days   Jul 4, 1826
# 2       65 years, 325 daysMar 4, 1809      17 years, 122 days   Jul 4, 1826
# 3       65 years, 353 daysMar 4, 1817      19 years, 116 days  Jun 28, 1836
# 4       66 years, 310 daysMar 4, 1825       6 years, 122 days   Jul 4, 1831
# 5       61 years, 236 daysMar 4, 1829      18 years, 356 days  Feb 23, 1848
# 6       69 years, 354 daysMar 4, 1837        8 years, 96 days   Jun 8, 1845
# 7        58 years, 89 daysMar 4, 1841      21 years, 142 days  Jul 24, 1862
# 8    68 years, 54 days Apr 4, 1841[b]                     NaN   Apr 4, 1841
# 9       54 years, 340 daysMar 4, 1845      16 years, 320 days  Jan 18, 1862
# 10      53 years, 122 daysMar 4, 1849                103 days  Jun 15, 1849
# 11   65 years, 227 daysJul 9, 1850[b]                     NaN   Jul 9, 1850
# 12       53 years, 56 daysMar 4, 1853        21 years, 4 days   Mar 8, 1874
# 13      52 years, 101 daysMar 4, 1857      12 years, 218 days   Oct 8, 1869
# 14      69 years, 315 daysMar 4, 1861        7 years, 89 days   Jun 1, 1868
# 15   56 years, 62 daysApr 15, 1865[b]                     NaN  Apr 15, 1865
# 16       60 years, 65 daysMar 4, 1869       6 years, 149 days  Jul 31, 1875
# 17      54 years, 311 daysMar 4, 1877       8 years, 141 days  Jul 23, 1885
# 18      58 years, 151 daysMar 4, 1881      11 years, 319 days  Jan 17, 1893
# 19  49 years, 304 daysSep 19, 1881[b]                     NaN  Sep 19, 1881
# 20      55 years, 150 daysMar 4, 1885        1 year, 259 days  Nov 18, 1886
# 21      51 years, 351 daysMar 4, 1889      4 years, 0 days[c]  Jun 24, 1908
# 22      59 years, 196 daysMar 4, 1893         8 years, 9 days  Mar 13, 1901
# 23      59 years, 351 daysMar 4, 1897   11 years, 112 days[d]  Jun 24, 1908
# 24  58 years, 228 daysSep 14, 1901[b]                     NaN  Sep 14, 1901
# 25      50 years, 128 daysMar 4, 1909       9 years, 308 days   Jan 6, 1919
# 26      55 years, 170 daysMar 4, 1913        17 years, 4 days   Mar 8, 1930
# 27       64 years, 66 daysMar 4, 1921       2 years, 336 days   Feb 3, 1924
# 28   57 years, 273 daysAug 2, 1923[b]                     NaN   Aug 2, 1923
# 29      56 years, 243 daysMar 4, 1929       3 years, 307 days   Jan 5, 1933
# 30      58 years, 206 daysMar 4, 1933      31 years, 230 days  Oct 20, 1964
# 31   63 years, 72 daysApr 12, 1945[b]                     NaN  Apr 12, 1945
# 32     68 years, 257 daysJan 20, 1953      19 years, 341 days  Dec 26, 1972
# 33      70 years, 98 daysJan 20, 1961        8 years, 67 days  Mar 28, 1969
# 34  46 years, 177 daysNov 22, 1963[b]                     NaN  Nov 22, 1963
# 35     60 years, 146 daysJan 20, 1969         4 years, 2 days  Jan 22, 1973
# 36   61 years, 212 daysAug 9, 1974[e]      19 years, 256 days  Apr 22, 1994
# 37     63 years, 190 daysJan 20, 1977      29 years, 340 days  Dec 26, 2006
# 38     56 years, 111 daysJan 20, 1981      38 years, 175 days      (living)
# 39     77 years, 349 daysJan 20, 1989      15 years, 137 days   Jun 5, 2004
# 40     68 years, 222 daysJan 20, 1993      25 years, 314 days  Nov 30, 2018
# 41     54 years, 154 daysJan 20, 2001      18 years, 175 days      (living)
# 42     62 years, 198 daysJan 20, 2009      10 years, 175 days      (living)
# 43     55 years, 169 daysJan 20, 2017       2 years, 175 days      (living)
#
#                    Age   First        Last
# 0   67 years, 295 days  George  Washington
# 1   90 years, 247 days    John       Adams
# 2    83 years, 82 days  Thomas   Jefferson
# 3   85 years, 104 days   James     Madison
# 4    73 years, 67 days   James      Monroe
# 5   80 years, 227 days     NaN         NaN
# 6    78 years, 85 days     NaN         NaN
# 7   79 years, 231 days     NaN         NaN
# 8    68 years, 54 days     NaN         NaN
# 9   71 years, 295 days     NaN         NaN
# 10  53 years, 225 days     NaN         NaN
# 11  65 years, 227 days     NaN         NaN
# 12   74 years, 60 days     NaN         NaN
# 13  64 years, 319 days     NaN         NaN
# 14   77 years, 39 days     NaN         NaN
# 15   56 years, 62 days     NaN         NaN
# 16  66 years, 214 days     NaN         NaN
# 17   63 years, 87 days     NaN         NaN
# 18  70 years, 105 days     NaN         NaN
# 19  49 years, 304 days     NaN         NaN
# 20   57 years, 44 days     NaN         NaN
# 21   71 years, 98 days     NaN         NaN
# 22  67 years, 205 days     NaN         NaN
# 23   71 years, 98 days     NaN         NaN
# 24  58 years, 228 days     NaN         NaN
# 25   60 years, 71 days     NaN         NaN
# 26  72 years, 174 days     NaN         NaN
# 27   67 years, 37 days     NaN         NaN
# 28  57 years, 273 days     NaN         NaN
# 29  60 years, 185 days     NaN         NaN
# 30   90 years, 71 days     NaN         NaN
# 31   63 years, 72 days     NaN         NaN
# 32  88 years, 232 days     NaN         NaN
# 33  78 years, 165 days     NaN         NaN
# 34  46 years, 177 days     NaN         NaN
# 35  64 years, 148 days     NaN         NaN
# 36  81 years, 103 days     NaN         NaN
# 37  93 years, 165 days     NaN         NaN
# 38  94 years, 286 days     NaN         NaN
# 39  93 years, 120 days     NaN         NaN
# 40  94 years, 171 days     NaN         NaN
# 41  72 years, 329 days     NaN         NaN
# 42    73 years, 8 days     NaN         NaN
# 43  57 years, 344 days     NaN         NaN

# %%
df = pd.read_csv('Admission_Predict.csv',index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df.where(df['TOEFL Score']>105)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1               337.0        118.0                4.0  4.5   4.5  9.65
# 2               324.0        107.0                4.0  4.0   4.5  8.87
# 3                 NaN          NaN                NaN  NaN   NaN   NaN
# 4               322.0        110.0                3.0  3.5   2.5  8.67
# 5                 NaN          NaN                NaN  NaN   NaN   NaN
# ...               ...          ...                ...  ...   ...   ...
# 396             324.0        110.0                3.0  3.5   3.5  9.04
# 397             325.0        107.0                3.0  3.0   3.5  9.11
# 398             330.0        116.0                4.0  5.0   4.5  9.45
# 399               NaN          NaN                NaN  NaN   NaN   NaN
# 400             333.0        117.0                4.0  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                1.0              0.92
# 2                1.0              0.76
# 3                NaN               NaN
# 4                1.0              0.80
# 5                NaN               NaN
# ...              ...               ...
# 396              1.0              0.82
# 397              1.0              0.84
# 398              1.0              0.91
# 399              NaN               NaN
# 400              1.0              0.95
#
# [400 rows x 8 columns]

# %%
df.drop('TOEFL Score',axis=1)
# Out:
#             GRE Score  University Rating  SOP  LOR   CGPA  Research  \
# Serial No.
# 1                 337                  4  4.5   4.5  9.65         1
# 2                 324                  4  4.0   4.5  8.87         1
# 3                 316                  3  3.0   3.5  8.00         1
# 4                 322                  3  3.5   2.5  8.67         1
# 5                 314                  2  2.0   3.0  8.21         0
# ...               ...                ...  ...   ...   ...       ...
# 396               324                  3  3.5   3.5  9.04         1
# 397               325                  3  3.0   3.5  9.11         1
# 398               330                  4  5.0   4.5  9.45         1
# 399               312                  3  3.5   4.0  8.78         0
# 400               333                  4  5.0   4.0  9.66         1
#
#             Chance of Admit
# Serial No.
# 1                       0.92
# 2                       0.76
# 3                       0.72
# 4                       0.80
# 5                       0.65
# ...                      ...
# 396                     0.82
# 397                     0.84
# 398                     0.91
# 399                     0.67
# 400                     0.95
#
# [400 rows x 7 columns]

# %%
s
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
df[(df['GRE Score'] > 300) & (df['GRE Score'] < 330)]
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# 7                 321          109                  3  3.0   4.0  8.20
# ...               ...          ...                ...  ...   ...   ...
# 394               317          104                  2  3.0   3.0  8.76
# 395               329          111                  4  4.5   4.0  9.23
# 396               324          110                  3  3.5   3.5  9.04
# 397               325          107                  3  3.0   3.5  9.11
# 399               312          103                  3  3.5   4.0  8.78
#
#             Research  Chance of Admit
# Serial No.
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65
# 7                  1              0.75
# ...              ...               ...
# 394                0              0.77
# 395                1              0.89
# 396                1              0.82
# 397                1              0.84
# 399                0              0.67
#
# [302 rows x 8 columns]

# %%
di = [{'Major':'Maths','Name':'Alice','Age':20,'Gender':'F'},
      {'Major':'Social','Name':'Jack','Age':25,'Gender':'M'}]
xdf = pd.DataFrame(di)
xdf
# Out:
#     Major   Name  Age Gender
# 0   Maths  Alice   20      F
# 1  Social   Jack   25      M

# %%
xdf = xdf.set_index('Major')
